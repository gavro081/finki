# %%
! pip install pandas numpy scikit-learn matplotlib seaborn xgboost
# Out:
# 13400.99s - pydevd: Sending message related to process being replaced timed-out after 5 seconds
# Requirement already satisfied: pandas in /Users/Filip/Desktop/faks/semestar-5/vnp/VNP_2025-26/.venv/lib/python3.13/site-packages (2.3.3)
# Requirement already satisfied: numpy in /Users/Filip/Desktop/faks/semestar-5/vnp/VNP_2025-26/.venv/lib/python3.13/site-packages (2.3.5)
# Requirement already satisfied: scikit-learn in /Users/Filip/Desktop/faks/semestar-5/vnp/VNP_2025-26/.venv/lib/python3.13/site-packages (1.7.2)
# Requirement already satisfied: matplotlib in /Users/Filip/Desktop/faks/semestar-5/vnp/VNP_2025-26/.venv/lib/python3.13/site-packages (3.10.7)
# Requirement already satisfied: seaborn in /Users/Filip/Desktop/faks/semestar-5/vnp/VNP_2025-26/.venv/lib/python3.13/site-packages (0.13.2)
# Collecting xgboost
#   Downloading xgboost-3.1.2-py3-none-macosx_12_0_arm64.whl.metadata (2.1 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/Filip/Desktop/faks/semestar-5/vnp/VNP_2025-26/.venv/lib/python3.13/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /Users/Filip/Desktop/faks/semestar-5/vnp/VNP_2025-26/.venv/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /Users/Filip/Desktop/faks/semestar-5/vnp/VNP_2025-26/.venv/lib/python3.13/site-packages (from pandas) (2025.2)
# Requirement already satisfied: scipy>=1.8.0 in /Users/Filip/Desktop/faks/semestar-5/vnp/VNP_2025-26/.venv/lib/python3.13/site-packages (from scikit-learn) (1.16.3)
# Requirement already satisfied: joblib>=1.2.0 in /Users/Filip/Desktop/faks/semestar-5/vnp/VNP_2025-26/.venv/lib/python3.13/site-packages (from scikit-learn) (1.5.2)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/Filip/Desktop/faks/semestar-5/vnp/VNP_2025-26/.venv/lib/python3.13/site-packages (from scikit-learn) (3.6.0)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/Filip/Desktop/faks/semestar-5/vnp/VNP_2025-26/.venv/lib/python3.13/site-packages (from matplotlib) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /Users/Filip/Desktop/faks/semestar-5/vnp/VNP_2025-26/.venv/lib/python3.13/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/Filip/Desktop/faks/semestar-5/vnp/VNP_2025-26/.venv/lib/python3.13/site-packages (from matplotlib) (4.60.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/Filip/Desktop/faks/semestar-5/vnp/VNP_2025-26/.venv/lib/python3.13/site-packages (from matplotlib) (1.4.9)
# Requirement already satisfied: packaging>=20.0 in /Users/Filip/Desktop/faks/semestar-5/vnp/VNP_2025-26/.venv/lib/python3.13/site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in /Users/Filip/Desktop/faks/semestar-5/vnp/VNP_2025-26/.venv/lib/python3.13/site-packages (from matplotlib) (12.0.0)
# Requirement already satisfied: pyparsing>=3 in /Users/Filip/Desktop/faks/semestar-5/vnp/VNP_2025-26/.venv/lib/python3.13/site-packages (from matplotlib) (3.2.5)
# Requirement already satisfied: six>=1.5 in /Users/Filip/Desktop/faks/semestar-5/vnp/VNP_2025-26/.venv/lib/python3.13/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
# Downloading xgboost-3.1.2-py3-none-macosx_12_0_arm64.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 2.5 MB/s eta 0:00:00a 0:00:01
# Installing collected packages: xgboost
# Successfully installed xgboost-3.1.2
#
# [notice] A new release of pip is available: 25.0 -> 25.3
# [notice] To update, run: pip install --upgrade pip

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.experimental import enable_iterative_imputer
from sklearn.impute import SimpleImputer, KNNImputer, IterativeImputer
from sklearn.preprocessing import (
    MinMaxScaler,
    LabelEncoder,
    OrdinalEncoder,
    PolynomialFeatures,
    StandardScaler
)

from sklearn.model_selection import train_test_split, cross_validate, GridSearchCV
from sklearn.metrics import (
    mean_absolute_error,
    mean_absolute_percentage_error,
    mean_squared_error,
    root_mean_squared_error,
    r2_score,
    confusion_matrix,
    classification_report,
)
from sklearn.linear_model import (
    LinearRegression,
    Lasso,
    Ridge,
    LassoCV,
    RidgeCV,
    LogisticRegression,
)
from sklearn.neighbors import KNeighborsRegressor, KNeighborsClassifier
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
import numpy as np

# %%
df_12 = pd.read_csv("data/season_12_data.csv")
df_13 = pd.read_csv("data/season_13_data.csv")

# %%
df_12.head()
# Out:
#      Name     Class Role Tier  Trend   Win %  Role % Pick %  \
# 0  Aatrox   Fighter  TOP    A   6.52  49.97%  94.62%  4.43%
# 1    Ahri      Mage  MID    A  -0.24  49.93%  93.47%  4.62%
# 2   Akali  Assassin  MID    S   6.51  48.59%  65.65%  8.16%
# 3   Akali  Assassin  TOP    A   3.34  48.57%  34.06%  4.24%
# 4  Akshan  Marksman  MID    S   0.65  51.46%  58.01%  4.83%
#
#                        Ban %   KDA
# 0    Blue (0.83%)/Red (1.2%)  1.97
# 1    Blue (0.2%)/Red (0.84%)  2.56
# 2   Blue (6.51%)/Red (6.37%)  2.34
# 3   Blue (5.57%)/Red (7.31%)  2.04
# 4  Blue (5.07%)/Red (16.84%)  2.23

# %%
df_13.head()
# Out:
#      Name     Class Role Tier  Trend   Win %  Role % Pick %  \
# 0  Aatrox   Fighter  TOP    S -31.86  47.68%  91.63%  6.62%
# 1    Ahri      Mage  MID    S   4.55  49.50%  94.65%  5.81%
# 2   Akali  Assassin  MID    S   4.33  48.41%  75.74%  8.11%
# 3   Akali  Assassin  TOP    C  -1.51  45.92%  23.50%  2.55%
# 4  Akshan  Marksman  MID    A   0.34  51.62%  66.03%  2.75%
#
#                        Ban %   KDA
# 0    Blue (9.8%)/Red (2.18%)  1.77
# 1   Blue (1.54%)/Red (0.19%)  2.58
# 2   Blue (5.74%)/Red (7.28%)  2.37
# 3  Blue (0.47%)/Red (12.55%)  2.00
# 4   Blue (0.06%)/Red (3.73%)  2.26

# %%
keys_to_strip = [key for key in df_12.keys() if "%" in key and key != "Ban %"]
keys_to_strip
# Out:
# ['Win %', 'Role %', 'Pick %']

# %%
df_12[keys_to_strip].isna().sum()
# Out:
# Win %     0
# Role %    0
# Pick %    0
# dtype: int64

# %%
def strip_percentage(df, columns):
    for col in columns:
        values = []
        for val in df[col]:
            values.append(float(val.split("%")[0]) if type(val) != float else np.nan)
        df[col] = values

# %%
import re

def handle_ban(df):
    values = []
    for val in df["Ban %"]:
        if type(val) == float:
            # nan
            values.append(np.nan)
        else:
            numbers = [float(n) for n in re.findall(r"\d+\.\d+", val)]
            values.append(sum(numbers))

    df["Ban %"] = values

# %%
strip_percentage(df_12, keys_to_strip)
strip_percentage(df_13, keys_to_strip)

# %%
handle_ban(df_12)
handle_ban(df_13)

# %%
df_12.head()
# Out:
#      Name     Class Role Tier  Trend  Win %  Role %  Pick %  Ban %   KDA
# 0  Aatrox   Fighter  TOP    A   6.52  49.97   94.62    4.43   2.03  1.97
# 1    Ahri      Mage  MID    A  -0.24  49.93   93.47    4.62   1.04  2.56
# 2   Akali  Assassin  MID    S   6.51  48.59   65.65    8.16  12.88  2.34
# 3   Akali  Assassin  TOP    A   3.34  48.57   34.06    4.24  12.88  2.04
# 4  Akshan  Marksman  MID    S   0.65  51.46   58.01    4.83  21.91  2.23

# %%
df_13.head()
# Out:
#      Name     Class Role Tier  Trend  Win %  Role %  Pick %  Ban %   KDA
# 0  Aatrox   Fighter  TOP    S -31.86  47.68   91.63    6.62  11.98  1.77
# 1    Ahri      Mage  MID    S   4.55  49.50   94.65    5.81   1.73  2.58
# 2   Akali  Assassin  MID    S   4.33  48.41   75.74    8.11  13.02  2.37
# 3   Akali  Assassin  TOP    C  -1.51  45.92   23.50    2.55  13.02  2.00
# 4  Akshan  Marksman  MID    A   0.34  51.62   66.03    2.75   3.79  2.26

# %%
for key in df_12.keys():
    if key in ["Name", "Role"]: continue
    df_12[f"{key} (season 12)"] = df_12[key]
    df_12.drop(columns=[key], inplace=True)

for key in df_13.keys():
    if key in ["Name", "Role"]: continue
    df_13[f"{key} (season 13)"] = df_13[key]
    df_13.drop(columns=[key], inplace=True)

# %%
# df_12.head()
df_13.head()
# Out:
#      Name Role Class (season 13) Tier (season 13)  Trend (season 13)  \
# 0  Aatrox  TOP           Fighter                S             -31.86
# 1    Ahri  MID              Mage                S               4.55
# 2   Akali  MID          Assassin                S               4.33
# 3   Akali  TOP          Assassin                C              -1.51
# 4  Akshan  MID          Marksman                A               0.34
#
#    Win % (season 13)  Role % (season 13)  Pick % (season 13)  \
# 0              47.68               91.63                6.62
# 1              49.50               94.65                5.81
# 2              48.41               75.74                8.11
# 3              45.92               23.50                2.55
# 4              51.62               66.03                2.75
#
#    Ban % (season 13)  KDA (season 13)
# 0              11.98             1.77
# 1               1.73             2.58
# 2              13.02             2.37
# 3              13.02             2.00
# 4               3.79             2.26

# %%
df = df_12.merge(df_13, on=["Name", "Role"], how="outer")
df.head()
# Out:
#      Name Role Class (season 12) Tier (season 12)  Trend (season 12)  \
# 0  Aatrox  TOP           Fighter                A               6.52
# 1    Ahri  MID              Mage                A              -0.24
# 2   Akali  MID          Assassin                S               6.51
# 3   Akali  TOP          Assassin                A               3.34
# 4  Akshan  MID          Marksman                S               0.65
#
#    Win % (season 12)  Role % (season 12)  Pick % (season 12)  \
# 0              49.97               94.62                4.43
# 1              49.93               93.47                4.62
# 2              48.59               65.65                8.16
# 3              48.57               34.06                4.24
# 4              51.46               58.01                4.83
#
#    Ban % (season 12)  KDA (season 12) Class (season 13) Tier (season 13)  \
# 0               2.03             1.97           Fighter                S
# 1               1.04             2.56              Mage                S
# 2              12.88             2.34          Assassin                S
# 3              12.88             2.04          Assassin                C
# 4              21.91             2.23          Marksman                A
#
#    Trend (season 13)  Win % (season 13)  Role % (season 13)  \
# 0             -31.86              47.68               91.63
# 1               4.55              49.50               94.65
# 2               4.33              48.41               75.74
# 3              -1.51              45.92               23.50
# 4               0.34              51.62               66.03
#
#    Pick % (season 13)  Ban % (season 13)  KDA (season 13)
# 0                6.62              11.98             1.77
# 1                5.81               1.73             2.58
# 2                8.11              13.02             2.37
# 3                2.55              13.02             2.00
# 4                2.75               3.79             2.26

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 258 entries, 0 to 257
# Data columns (total 18 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                258 non-null    object
#  1   Role                258 non-null    object
#  2   Class (season 12)   231 non-null    object
#  3   Tier (season 12)    232 non-null    object
#  4   Trend (season 12)   232 non-null    float64
#  5   Win % (season 12)   232 non-null    float64
#  6   Role % (season 12)  232 non-null    float64
#  7   Pick % (season 12)  232 non-null    float64
#  8   Ban % (season 12)   232 non-null    float64
#  9   KDA (season 12)     232 non-null    float64
#  10  Class (season 13)   244 non-null    object
#  11  Tier (season 13)    244 non-null    object
#  12  Trend (season 13)   244 non-null    float64
#  13  Win % (season 13)   244 non-null    float64
#  14  Role % (season 13)  244 non-null    float64
#  15  Pick % (season 13)  244 non-null    float64
#  16  Ban % (season 13)   244 non-null    float64
#  17  KDA (season 13)     244 non-null    float64
# dtypes: float64(12), object(6)
# memory usage: 36.4+ KB

# %%
df.isna().sum()
# Out:
# Name                   0
# Role                   0
# Class (season 12)     27
# Tier (season 12)      26
# Trend (season 12)     26
# Win % (season 12)     26
# Role % (season 12)    26
# Pick % (season 12)    26
# Ban % (season 12)     26
# KDA (season 12)       26
# Class (season 13)     14
# Tier (season 13)      14
# Trend (season 13)     14
# Win % (season 13)     14
# Role % (season 13)    14
# Pick % (season 13)    14
# Ban % (season 13)     14
# KDA (season 13)       14
# dtype: int64

# %%
df_tmp = df[
    (df["Class (season 12)"].notna()) &
    (df["Class (season 13)"].notna()) &
    (df["Class (season 12)"] != df["Class (season 13)"])]
len(df_tmp)
# Out:
# 0

# %%
len(df[
    (df["Class (season 12)"].isna()) &
    (df["Class (season 13)"].isna()) 
])
# Out:
# 0

# %%
plt.figure(figsize=(18, 12))
sns.heatmap(df.corr(numeric_only=True), annot=True)
# Out:
# <Axes: >

# %%
# ne postoi nieden heroj kaj sto klasata od edna sezona vo druga se smenila, 
# moze klasata da se imputira preku klasata od drugata sezona

# class, role %, pick %, kda,  moze da se zemat od drugata sezona
# tier, trend, win %, ban % ne moze

# %%
label_encoder = LabelEncoder()
df["Class (season 12)"] = label_encoder.fit_transform(df["Class (season 12)"])
df["Class (season 13)"] = label_encoder.transform(df["Class (season 13)"])
label_encoder.classes_
# Out:
# array(['Assassin', 'Fighter', 'Mage', 'Marksman', 'Support', 'Tank', nan],
#       dtype=object)

# %%
col1 = "Class (season 12)"
col2 = "Class (season 13)"
df[[col1, col2]] = df[[col1, col2]].replace(6, np.nan)

# %%
cols = ["Class", "Role %", "Pick %", "KDA"]
for col in cols:
    values_season_12 = df[f"{col} (season 12)"]
    values_season_13 = df[f"{col} (season 13)"]

    to_remove = []
    assert len(values_season_12) == len(values_season_13)
    for i in range(len(values_season_12)):
        val12 = values_season_12[i]
        val13 = values_season_13[i]
        
        if np.isnan(val12) and np.isnan(val13):
            to_remove.append(i)
        if np.isnan(val12):
            values_season_12[i] = val13
        elif np.isnan(val13):
            values_season_13[i] = val12
    
df[f"{col} (season 12)"] = values_season_12    
df[f"{col} (season 13)"] = values_season_13
# Out:
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_13[i] = val12
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13
# /var/folders/g8/z4hc_3fn2m31gh607khncy_h0000gn/T/ipykernel_6611/1344237618.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   values_season_12[i] = val13

# %%
df.isna().sum()
# Out:
# Name                   0
# Role                   0
# Class (season 12)      0
# Tier (season 12)      26
# Trend (season 12)     26
# Win % (season 12)     26
# Role % (season 12)     0
# Pick % (season 12)     0
# Ban % (season 12)     26
# KDA (season 12)        0
# Class (season 13)      0
# Tier (season 13)      14
# Trend (season 13)     14
# Win % (season 13)     14
# Role % (season 13)     0
# Pick % (season 13)     0
# Ban % (season 13)     14
# KDA (season 13)        0
# dtype: int64

# %%
df["Trend (season 13)"].plot.hist() # moze median
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["Win % (season 12)"].plot.hist() # moze median
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["Ban % (season 13)"].plot.hist() # moze median
# Out:
# <Axes: ylabel='Frequency'>

# %%
df["Tier (season 13)"].value_counts() # ke mi treba za target, ke go razgledam posle
# Out:
# Tier (season 13)
# A     61
# B     61
# C     37
# S     36
# D     25
# S+    24
# Name: count, dtype: int64

# %%
median_imputer = SimpleImputer(strategy="median")
cols = ["Trend (season 12)", "Trend (season 13)", 
        "Win % (season 12)", "Win % (season 13)",
        "Ban % (season 12)", "Ban % (season 13)"]
for col in cols:
    df[[col]] = median_imputer.fit_transform(df[[col]])

# %%
assert len(df[df["Tier (season 13)"].isna() & 
    df["Tier (season 12)"].isna()]) == 0

# nema niedno kaj so dvete se nan

# %%
tier_season_12 = df["Tier (season 12)"]
tier_season_13 = df["Tier (season 13)"]
target_vals = []
for i in range(len(df)):
    tier_12 = tier_season_12[i]
    tier_13 = tier_season_13[i]
    
    # bidejki imame stringovi namesto da proveruvam dali e nan proveruvam dali e float, ako e float znaci deka e nan

    predicate1 = type(tier_12) != float and tier_12 == "S+" 
    predicate2 = type(tier_13) != float and tier_13 in ["S", "S+"]

    target_vals.append(1 if predicate1 or predicate2 else 0) 
    
df.drop(columns=["Tier (season 12)", "Tier (season 13)"], inplace=True)
df["World Cup Suitable"] = target_vals

# %%
df.head()
# Out:
#      Name Role  Class (season 12)  Trend (season 12)  Win % (season 12)  \
# 0  Aatrox  TOP                1.0               6.52              49.97
# 1    Ahri  MID                2.0              -0.24              49.93
# 2   Akali  MID                0.0               6.51              48.59
# 3   Akali  TOP                0.0               3.34              48.57
# 4  Akshan  MID                3.0               0.65              51.46
#
#    Role % (season 12)  Pick % (season 12)  Ban % (season 12)  KDA (season 12)  \
# 0               94.62                4.43               2.03             1.97
# 1               93.47                4.62               1.04             2.56
# 2               65.65                8.16              12.88             2.34
# 3               34.06                4.24              12.88             2.04
# 4               58.01                4.83              21.91             2.23
#
#    Class (season 13)  Trend (season 13)  Win % (season 13)  \
# 0                1.0             -31.86              47.68
# 1                2.0               4.55              49.50
# 2                0.0               4.33              48.41
# 3                0.0              -1.51              45.92
# 4                3.0               0.34              51.62
#
#    Role % (season 13)  Pick % (season 13)  Ban % (season 13)  KDA (season 13)  \
# 0               91.63                6.62              11.98             1.77
# 1               94.65                5.81               1.73             2.58
# 2               75.74                8.11              13.02             2.37
# 3               23.50                2.55              13.02             2.00
# 4               66.03                2.75               3.79             2.26
#
#    World Cup Suitable
# 0                   1
# 1                   1
# 2                   1
# 3                   0
# 4                   0

# %%
df.isna().sum()
# Out:
# Name                  0
# Role                  0
# Class (season 12)     0
# Trend (season 12)     0
# Win % (season 12)     0
# Role % (season 12)    0
# Pick % (season 12)    0
# Ban % (season 12)     0
# KDA (season 12)       0
# Class (season 13)     0
# Trend (season 13)     0
# Win % (season 13)     0
# Role % (season 13)    0
# Pick % (season 13)    0
# Ban % (season 13)     0
# KDA (season 13)       0
# World Cup Suitable    0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 258 entries, 0 to 257
# Data columns (total 17 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Name                258 non-null    object
#  1   Role                258 non-null    object
#  2   Class (season 12)   258 non-null    float64
#  3   Trend (season 12)   258 non-null    float64
#  4   Win % (season 12)   258 non-null    float64
#  5   Role % (season 12)  258 non-null    float64
#  6   Pick % (season 12)  258 non-null    float64
#  7   Ban % (season 12)   258 non-null    float64
#  8   KDA (season 12)     258 non-null    float64
#  9   Class (season 13)   258 non-null    float64
#  10  Trend (season 13)   258 non-null    float64
#  11  Win % (season 13)   258 non-null    float64
#  12  Role % (season 13)  258 non-null    float64
#  13  Pick % (season 13)  258 non-null    float64
#  14  Ban % (season 13)   258 non-null    float64
#  15  KDA (season 13)     258 non-null    float64
#  16  World Cup Suitable  258 non-null    int64
# dtypes: float64(14), int64(1), object(2)
# memory usage: 34.4+ KB

# %%
len(df["Name"].unique())
# Out:
# 162

# %%
df.drop(columns=["Name"], inplace=True)

# %%
len(df["Role"].unique())
# Out:
# 5

# %%
df["Role"].value_counts()
# Out:
# Role
# TOP        64
# MID        64
# SUPPORT    51
# JUNGLE     50
# ADC        29
# Name: count, dtype: int64

# %%
label_encoder = LabelEncoder()
df["Role"] = label_encoder.fit_transform(df["Role"])
df["Role"].value_counts()
# Out:
# Role
# 4    64
# 2    64
# 3    51
# 1    50
# 0    29
# Name: count, dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 258 entries, 0 to 257
# Data columns (total 16 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Role                258 non-null    int64
#  1   Class (season 12)   258 non-null    float64
#  2   Trend (season 12)   258 non-null    float64
#  3   Win % (season 12)   258 non-null    float64
#  4   Role % (season 12)  258 non-null    float64
#  5   Pick % (season 12)  258 non-null    float64
#  6   Ban % (season 12)   258 non-null    float64
#  7   KDA (season 12)     258 non-null    float64
#  8   Class (season 13)   258 non-null    float64
#  9   Trend (season 13)   258 non-null    float64
#  10  Win % (season 13)   258 non-null    float64
#  11  Role % (season 13)  258 non-null    float64
#  12  Pick % (season 13)  258 non-null    float64
#  13  Ban % (season 13)   258 non-null    float64
#  14  KDA (season 13)     258 non-null    float64
#  15  World Cup Suitable  258 non-null    int64
# dtypes: float64(14), int64(2)
# memory usage: 32.4 KB

# %%
TARGET = "World Cup Suitable"
df[TARGET].value_counts()
# Out:
# World Cup Suitable
# 0    194
# 1     64
# Name: count, dtype: int64

# %%
target_0 = df[df[TARGET] == 0].sample(100)
target_1 = df[df[TARGET] == 1]

# %%
final_df = pd.concat([target_0, target_1], ignore_index=True) # pazi ignore index e mn bitno 
final_df = final_df.sample(len(final_df))
final_df.head()
# Out:
#      Role  Class (season 12)  Trend (season 12)  Win % (season 12)  \
# 141     4                1.0             15.560             49.600
# 58      2                2.0              5.180             50.920
# 95      3                4.0              2.270             50.230
# 85      2                5.0             -4.650             49.570
# 38      2                3.0             -0.815             49.885
#
#      Role % (season 12)  Pick % (season 12)  Ban % (season 12)  \
# 141               83.89                8.23               7.37
# 58                91.35                3.43               3.03
# 95                98.67                4.05               1.00
# 85                17.42                0.55               0.95
# 38                11.07                0.17               2.39
#
#      KDA (season 12)  Class (season 13)  Trend (season 13)  Win % (season 13)  \
# 141             1.76                1.0              -9.00              50.30
# 58              2.22                2.0              -0.67              51.52
# 95              2.97                4.0              -0.29              50.30
# 85              2.37                5.0              -1.60              53.13
# 38              2.29                3.0              -9.78              51.07
#
#      Role % (season 13)  Pick % (season 13)  Ban % (season 13)  \
# 141               81.83                7.40               4.49
# 58                90.90                3.69               3.69
# 95                97.18                3.25               0.48
# 85                20.82                0.45               0.76
# 38                11.07                0.17               0.60
#
#      KDA (season 13)  World Cup Suitable
# 141             1.78                   1
# 58              2.35                   0
# 95              3.10                   0
# 85              2.47                   0
# 38              2.29                   0

# %%
X_train, X_test, Y_train, Y_test = train_test_split(final_df[final_df.columns[:-1]],  final_df[TARGET], test_size=0.2)

# %%
from xgboost import XGBClassifier

model = XGBClassifier(max_depth=50, min_child_weight=1, n_estimators=200, n_jobs=-1, verbose=1, learning_rate=0.16)
model.fit(X_train, Y_train)

y_pred = model.predict(X_test)
# Out:
# /Users/Filip/Desktop/faks/semestar-5/vnp/VNP_2025-26/.venv/lib/python3.13/site-packages/xgboost/training.py:199: UserWarning: [18:59:57] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:790:
# Parameters: { "verbose" } are not used.
#
#   bst.update(dtrain, iteration=i, fobj=obj)

# %%
from sklearn import metrics
print("Accuracy:", metrics.accuracy_score(Y_test, y_pred))

print(confusion_matrix(Y_test, y_pred))
print(classification_report(Y_test, y_pred))
# Out:
# Accuracy: 0.9696969696969697
# [[18  1]
#  [ 0 14]]
#               precision    recall  f1-score   support
#
#            0       1.00      0.95      0.97        19
#            1       0.93      1.00      0.97        14
#
#     accuracy                           0.97        33
#    macro avg       0.97      0.97      0.97        33
# weighted avg       0.97      0.97      0.97        33
